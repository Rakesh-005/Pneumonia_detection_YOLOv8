# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.94-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Downloading ultralytics-8.3.94-py3-none-any.whl (949 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 30.1 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.94 ultralytics-thop-2.0.14

# %%
import torch
from ultralytics import YOLO
import os
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model_path = "/kaggle/input/best-model-roboflow/best.pt"  # Update with correct path
model = YOLO(model_path)

# %%
dataset_yaml = """
path: /kaggle/input/chest-xray-pneumonia/chest_xray  # Base dataset path
train: train  # Train images folder
val: val  # Validation images folder
test: test  # Test images folder

nc: 2  # Number of classes (Normal, Pneumonia)
names: ['Normal', 'Pneumonia']
"""

with open("dataset.yaml", "w") as f:
    f.write(dataset_yaml)

print("✅ dataset.yaml created successfully!")
# Out:
# ✅ dataset.yaml created successfully!

# %%
from ultralytics import YOLO
import os
import torch
import gc
import pandas as pd
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

# Load YOLO Model (Use GPU if available, else CPU)
model_path = "/kaggle/input/best-model-roboflow/best.pt"  
device = "cuda" if torch.cuda.is_available() else "cpu"
model = YOLO(model_path).to(device)

# Define Dataset Paths
dataset_path = "/kaggle/input/chest-xray-pneumonia/chest_xray"
splits = ["train", "val", "test"]
categories = ["NORMAL", "PNEUMONIA"]

# ✅ Initialize dictionary to store evaluation results
results = {}

def evaluate_model(split):
    y_true = []
    y_pred = []
    total_images = 0  # Counter to track processed images

    print(f"\nProcessing {split} dataset...")

    for category in categories:
        folder_path = os.path.join(dataset_path, split, category)

        for idx, image_name in enumerate(os.listdir(folder_path)):
            image_path = os.path.join(folder_path, image_name)

            # ✅ FIX: Use a different variable name instead of 'results'
            yolo_results = model(image_path, verbose=False)  # Avoid overwriting 'results' dict

            # Extract Detected Class Labels
            detected_classes = []
            for result in yolo_results:
                if result.boxes is not None:
                    detected_classes.extend(result.boxes.cls.tolist())

            # Determine Final Prediction
            pred_class = max(set(detected_classes), key=detected_classes.count) if detected_classes else 0
            actual_class = 0 if category == "NORMAL" else 1

            # Store Ground Truth & Predictions
            y_true.append(actual_class)
            y_pred.append(pred_class)

            # Update Image Counter
            total_images += 1
            print(f"Processed Image {total_images}: {image_path}")

            # Free GPU Memory Every 50 Iterations
            if idx % 50 == 0:
                torch.cuda.empty_cache()
                gc.collect()

    # Compute Confusion Matrix
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    # Compute Evaluation Metrics
    accuracy = (tp + tn) / (tp + tn + fp + fn) * 100
    precision = precision_score(y_true, y_pred) * 100
    recall = recall_score(y_true, y_pred) * 100
    specificity = (tn / (tn + fp)) * 100
    f1 = f1_score(y_true, y_pred) * 100
    fpr = (fp / (fp + tn)) * 100

    # ✅ FIX: Store results correctly
    results[split] = {
        "Accuracy (%)": round(accuracy, 2),
        "Precision (%)": round(precision, 2),
        "Recall (Sensitivity) (%)": round(recall, 2),
        "Specificity (%)": round(specificity, 2),
        "F1 Score (%)": round(f1, 2),
        "False Positive Rate (FPR) (%)": round(fpr, 2),
    }

    print(f"\nFinished processing {split} dataset. Total images processed: {total_images}")

# Run Evaluation on all splits
for split in splits:
    evaluate_model(split)

# Convert results to DataFrame
df = pd.DataFrame.from_dict(results, orient="index")

# Print formatted table
print("\nFinal Evaluation Metrics:")
print(df.to_markdown(tablefmt="fancy_grid"))
# Out:
# Processing train dataset...
# Processed Image 1: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0771-0001.jpeg
# Processed Image 2: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1294-0001-0002.jpeg
# Processed Image 3: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0675-0001.jpeg
# Processed Image 4: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1169-0001.jpeg
# Processed Image 5: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0421-0001.jpeg
# Processed Image 6: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0531-0001.jpeg
# Processed Image 7: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0416-0001-0002.jpeg
# Processed Image 8: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0965-0001.jpeg
# Processed Image 9: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0627-0001.jpeg
# Processed Image 10: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0997-0001.jpeg
# Processed Image 11: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0757-0001.jpeg
# Processed Image 12: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0629-0001-0002.jpeg
# Processed Image 13: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0588-0001.jpeg
# Processed Image 14: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0713-0001.jpeg
# Processed Image 15: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0696-0001.jpeg
# Processed Image 16: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0808-0001.jpeg
# Processed Image 17: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1126-0001.jpeg
# Processed Image 18: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0701-0001.jpeg
# Processed Image 19: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1046-0001.jpeg
# Processed Image 20: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0304-0001.jpeg
# Processed Image 21: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0385-0001.jpeg
# Processed Image 22: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0908-0001.jpeg
# Processed Image 23: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1301-0001.jpeg
# Processed Image 24: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0428-0001.jpeg
# Processed Image 25: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1318-0001.jpeg
# Processed Image 26: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0626-0001-0001.jpeg
# Processed Image 27: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0399-0001.jpeg
# Processed Image 28: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0452-0001.jpeg
# Processed Image 29: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0672-0001.jpeg
# Processed Image 30: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0314-0001.jpeg
# Processed Image 31: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0578-0001.jpeg
# Processed Image 32: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1171-0001.jpeg
# Processed Image 33: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1401-0001.jpeg
# Processed Image 34: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0313-0001.jpeg
# Processed Image 35: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0461-0001.jpeg
# Processed Image 36: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0578-0001.jpeg
# Processed Image 37: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0613-0001.jpeg
# Processed Image 38: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0320-0001.jpeg
# Processed Image 39: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0624-0001-0002.jpeg
# Processed Image 40: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0460-0001.jpeg
# Processed Image 41: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0490-0001.jpeg
# Processed Image 42: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0640-0001-0001.jpeg
# Processed Image 43: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0678-0001.jpeg
# Processed Image 44: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0623-0001.jpeg
# Processed Image 45: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0620-0001-0002.jpeg
# Processed Image 46: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0505-0001-0002.jpeg
# Processed Image 47: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0562-0001.jpeg
# Processed Image 48: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0209-0001.jpeg
# Processed Image 49: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0453-0001-0002.jpeg
# Processed Image 50: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1161-0001.jpeg
# Processed Image 51: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0555-0001-0002.jpeg
# Processed Image 52: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0875-0001.jpeg
# Processed Image 53: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1242-0001.jpeg
# Processed Image 54: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0622-0001.jpeg
# Processed Image 55: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0630-0001.jpeg
# Processed Image 56: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0950-0001.jpeg
# Processed Image 57: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1290-0001.jpeg
# Processed Image 58: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0998-0001.jpeg
# Processed Image 59: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0642-0001.jpeg
# Processed Image 60: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0927-0001.jpeg
# Processed Image 61: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0619-0001.jpeg
# Processed Image 62: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0393-0001.jpeg
# Processed Image 63: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0556-0001.jpeg
# Processed Image 64: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0447-0001.jpeg
# Processed Image 65: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0340-0001.jpeg
# Processed Image 66: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0853-0001.jpeg
# Processed Image 67: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0526-0001.jpeg
# Processed Image 68: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1154-0001-0001.jpeg
# Processed Image 69: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0723-0001.jpeg
# Processed Image 70: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0343-0001.jpeg
# Processed Image 71: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0640-0001.jpeg
# Processed Image 72: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0419-0001.jpeg
# Processed Image 73: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0525-0001-0002.jpeg
# Processed Image 74: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0690-0001.jpeg
# Processed Image 75: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1132-0001.jpeg
# Processed Image 76: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0298-0001.jpeg
# Processed Image 77: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0705-0001.jpeg
# Processed Image 78: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0137-0001.jpeg
# Processed Image 79: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0536-0001.jpeg
# Processed Image 80: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0705-0001.jpeg
# Processed Image 81: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0553-0001-0001.jpeg
# Processed Image 82: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1118-0001.jpeg
# Processed Image 83: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0283-0001.jpeg
# Processed Image 84: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0353-0001.jpeg
# Processed Image 85: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0695-0001.jpeg
# Processed Image 86: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0900-0001.jpeg
# Processed Image 87: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0533-0001-0001.jpeg
# Processed Image 88: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0481-0001.jpeg
# Processed Image 89: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0160-0001.jpeg
# Processed Image 90: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0635-0001.jpeg
# Processed Image 91: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0737-0001.jpeg
# Processed Image 92: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1039-0001.jpeg
# Processed Image 93: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0323-0001.jpeg
# Processed Image 94: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0318-0001.jpeg
# Processed Image 95: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0460-0001.jpeg
# Processed Image 96: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0402-0001.jpeg
# Processed Image 97: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0453-0001.jpeg
# Processed Image 98: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1376-0001.jpeg
# Processed Image 99: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0957-0001.jpeg
# Processed Image 100: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0523-0001-0001.jpeg
# Processed Image 101: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0824-0001.jpeg
# Processed Image 102: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0317-0001.jpeg
# Processed Image 103: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1196-0001.jpeg
# Processed Image 104: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0335-0001.jpeg
# Processed Image 105: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0626-0001.jpeg
# Processed Image 106: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0952-0001.jpeg
# Processed Image 107: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1231-0001.jpeg
# Processed Image 108: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0499-0001.jpeg
# Processed Image 109: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0443-0001.jpeg
# Processed Image 110: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1289-0001.jpeg
# Processed Image 111: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0892-0001.jpeg
# Processed Image 112: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0448-0001.jpeg
# Processed Image 113: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0693-0001.jpeg
# Processed Image 114: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0668-0001.jpeg
# Processed Image 115: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0650-0001.jpeg
# Processed Image 116: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0658-0001.jpeg
# Processed Image 117: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0747-0001.jpeg
# Processed Image 118: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0649-0001.jpeg
# Processed Image 119: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0509-0001.jpeg
# Processed Image 120: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0439-0001-0002.jpeg
# Processed Image 121: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0242-0001.jpeg
# Processed Image 122: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1365-0001.jpeg
# Processed Image 123: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0553-0001-0002.jpeg
# Processed Image 124: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1020-0001-0002.jpeg
# Processed Image 125: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0640-0001-0002.jpeg
# Processed Image 126: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1162-0001.jpeg
# Processed Image 127: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1184-0001.jpeg
# Processed Image 128: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0266-0001.jpeg
# Processed Image 129: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0547-0001.jpeg
# Processed Image 130: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1144-0001.jpeg
# Processed Image 131: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1176-0001.jpeg
# Processed Image 132: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0910-0001.jpeg
# Processed Image 133: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1274-0001.jpeg
# Processed Image 134: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1269-0001-0001.jpeg
# Processed Image 135: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0502-0001.jpeg
# Processed Image 136: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1269-0001-0002.jpeg
# Processed Image 137: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0507-0001.jpeg
# Processed Image 138: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0364-0001.jpeg
# Processed Image 139: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0645-0001.jpeg
# Processed Image 140: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0363-0001.jpeg
# Processed Image 141: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0381-0001.jpeg
# Processed Image 142: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0308-0001.jpeg
# Processed Image 143: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0471-0001.jpeg
# Processed Image 144: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0668-0001.jpeg
# Processed Image 145: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0587-0001.jpeg
# Processed Image 146: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0526-0001.jpeg
# Processed Image 147: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0873-0001.jpeg
# Processed Image 148: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0525-0001.jpeg
# Processed Image 149: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0302-0001.jpeg
# Processed Image 150: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0809-0001.jpeg
# Processed Image 151: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0357-0001.jpeg
# Processed Image 152: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0640-0001.jpeg
# Processed Image 153: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0555-0001.jpeg
# Processed Image 154: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0441-0001.jpeg
# Processed Image 155: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0539-0001.jpeg
# Processed Image 156: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0906-0001.jpeg
# Processed Image 157: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0677-0001.jpeg
# Processed Image 158: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1396-0001.jpeg
# Processed Image 159: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0652-0001.jpeg
# Processed Image 160: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0609-0001.jpeg
# Processed Image 161: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0741-0001.jpeg
# Processed Image 162: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0670-0001.jpeg
# Processed Image 163: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0492-0001.jpeg
# Processed Image 164: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0652-0001.jpeg
# Processed Image 165: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0347-0001.jpeg
# Processed Image 166: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1073-0001.jpeg
# Processed Image 167: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1303-0001.jpeg
# Processed Image 168: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0458-0001.jpeg
# Processed Image 169: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0659-0001.jpeg
# Processed Image 170: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0481-0001.jpeg
# Processed Image 171: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0401-0001.jpeg
# Processed Image 172: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0838-0001.jpeg
# Processed Image 173: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1294-0001.jpeg
# Processed Image 174: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0930-0001.jpeg
# Processed Image 175: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0962-0001.jpeg
# Processed Image 176: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0993-0001.jpeg
# Processed Image 177: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0454-0001.jpeg
# Processed Image 178: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0575-0001.jpeg
# Processed Image 179: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1157-0001.jpeg
# Processed Image 180: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0960-0001.jpeg
# Processed Image 181: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0620-0001-0001.jpeg
# Processed Image 182: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0483-0001.jpeg
# Processed Image 183: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1423-0001.jpeg
# Processed Image 184: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0505-0001-0001.jpeg
# Processed Image 185: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0337-0001.jpeg
# Processed Image 186: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1090-0001.jpeg
# Processed Image 187: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0533-0001.jpeg
# Processed Image 188: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0276-0001.jpeg
# Processed Image 189: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0651-0004.jpeg
# Processed Image 190: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0846-0001.jpeg
# Processed Image 191: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0667-0001.jpeg
# Processed Image 192: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0499-0001-0001.jpeg
# Processed Image 193: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1293-0001.jpeg
# Processed Image 194: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1243-0001.jpeg
# Processed Image 195: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1044-0001.jpeg
# Processed Image 196: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0557-0001.jpeg
# Processed Image 197: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0660-0001.jpeg
# Processed Image 198: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0424-0001.jpeg
# Processed Image 199: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1214-0001.jpeg
# Processed Image 200: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0329-0001.jpeg
# Processed Image 201: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0907-0001.jpeg
# Processed Image 202: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0435-0001.jpeg
# Processed Image 203: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0133-0001.jpeg
# Processed Image 204: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0457-0001.jpeg
# Processed Image 205: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0877-0001.jpeg
# Processed Image 206: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0253-0001.jpeg
# Processed Image 207: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1177-0001.jpeg
# Processed Image 208: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0491-0001-0001.jpeg
# Processed Image 209: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0372-0001.jpeg
# Processed Image 210: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0513-0001.jpeg
# Processed Image 211: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0611-0001.jpeg
# Processed Image 212: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0631-0001.jpeg
# Processed Image 213: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0604-0001.jpeg
# Processed Image 214: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0852-0001.jpeg
# Processed Image 215: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1026-0001.jpeg
# Processed Image 216: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0517-0001.jpeg
# Processed Image 217: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0669-0001.jpeg
# Processed Image 218: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0170-0001.jpeg
# Processed Image 219: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0450-0001.jpeg
# Processed Image 220: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0608-0001.jpeg
# Processed Image 221: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0732-0001.jpeg
# Processed Image 222: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0748-0001.jpeg
# Processed Image 223: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0543-0001.jpeg
# Processed Image 224: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0685-0001.jpeg
# Processed Image 225: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0361-0001.jpeg
# Processed Image 226: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0414-0001.jpeg
# Processed Image 227: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0408-0001.jpeg
# Processed Image 228: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1116-0001.jpeg
# Processed Image 229: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0637-0001.jpeg
# Processed Image 230: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1086-0001.jpeg
# Processed Image 231: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0326-0001.jpeg
# Processed Image 232: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0956-0001.jpeg
# Processed Image 233: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0564-0001.jpeg
# Processed Image 234: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0820-0001.jpeg
# Processed Image 235: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1053-0001.jpeg
# Processed Image 236: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1033-0001.jpeg
# Processed Image 237: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0643-0001.jpeg
# Processed Image 238: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0280-0001.jpeg
# Processed Image 239: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0814-0001.jpeg
# Processed Image 240: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0261-0001.jpeg
# Processed Image 241: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0718-0001.jpeg
# Processed Image 242: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0655-0001.jpeg
# Processed Image 243: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0699-0001.jpeg
# Processed Image 244: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1114-0001.jpeg
# Processed Image 245: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0660-0001-0001.jpeg
# Processed Image 246: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1314-0001.jpeg
# Processed Image 247: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0520-0001.jpeg
# Processed Image 248: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0348-0001.jpeg
# Processed Image 249: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1422-0001.jpeg
# Processed Image 250: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0413-0001.jpeg
# Processed Image 251: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0848-0001.jpeg
# Processed Image 252: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0154-0001.jpeg
# Processed Image 253: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0249-0001.jpeg
# Processed Image 254: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0588-0001.jpeg
# Processed Image 255: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0659-0001.jpeg
# Processed Image 256: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0500-0001.jpeg
# Processed Image 257: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0469-0001.jpeg
# Processed Image 258: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0388-0001.jpeg
# Processed Image 259: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1190-0001.jpeg
# Processed Image 260: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0377-0001.jpeg
# Processed Image 261: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1067-0001.jpeg
# Processed Image 262: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0231-0001.jpeg
# Processed Image 263: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0698-0001.jpeg
# Processed Image 264: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0869-0001.jpeg
# Processed Image 265: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0700-0001.jpeg
# Processed Image 266: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0437-0001-0001.jpeg
# Processed Image 267: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0467-0001.jpeg
# Processed Image 268: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0305-0001.jpeg
# Processed Image 269: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1128-0001.jpeg
# Processed Image 270: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0674-0001.jpeg
# Processed Image 271: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0566-0001.jpeg
# Processed Image 272: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0681-0001.jpeg
# Processed Image 273: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1304-0001.jpeg
# Processed Image 274: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1094-0001.jpeg
# Processed Image 275: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0655-0001.jpeg
# Processed Image 276: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0665-0001.jpeg
# Processed Image 277: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0736-0001.jpeg
# Processed Image 278: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0721-0001.jpeg
# Processed Image 279: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0265-0001.jpeg
# Processed Image 280: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0976-0001.jpeg
# Processed Image 281: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1201-0001.jpeg
# Processed Image 282: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0707-0001.jpeg
# Processed Image 283: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0555-0001-0001.jpeg
# Processed Image 284: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0727-0001.jpeg
# Processed Image 285: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1111-0001.jpeg
# Processed Image 286: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0926-0001.jpeg
# Processed Image 287: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0451-0001.jpeg
# Processed Image 288: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0917-0001.jpeg
# Processed Image 289: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1281-0001.jpeg
# Processed Image 290: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0427-0001.jpeg
# Processed Image 291: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0430-0001.jpeg
# Processed Image 292: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0898-0001.jpeg
# Processed Image 293: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0389-0001.jpeg
# Processed Image 294: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0151-0001.jpeg
# Processed Image 295: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0533-0001.jpeg
# Processed Image 296: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0414-0001.jpeg
# Processed Image 297: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0488-0001.jpeg
# Processed Image 298: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0511-0001.jpeg
# Processed Image 299: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0752-0001.jpeg
# Processed Image 300: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1002-0001.jpeg
# Processed Image 301: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0475-0001.jpeg
# Processed Image 302: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1125-0001.jpeg
# Processed Image 303: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0493-0001.jpeg
# Processed Image 304: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0465-0001.jpeg
# Processed Image 305: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0444-0001.jpeg
# Processed Image 306: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0243-0001.jpeg
# Processed Image 307: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0535-0001.jpeg
# Processed Image 308: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0519-0001-0001.jpeg
# Processed Image 309: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1206-0001.jpeg
# Processed Image 310: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0618-0001.jpeg
# Processed Image 311: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0755-0001.jpeg
# Processed Image 312: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1056-0001.jpeg
# Processed Image 313: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0472-0001.jpeg
# Processed Image 314: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0439-0001-0001.jpeg
# Processed Image 315: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0375-0001.jpeg
# Processed Image 316: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0519-0001.jpeg
# Processed Image 317: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0474-0001.jpeg
# Processed Image 318: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0629-0001.jpeg
# Processed Image 319: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0812-0001.jpeg
# Processed Image 320: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0474-0001.jpeg
# Processed Image 321: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0532-0001.jpeg
# Processed Image 322: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0420-0001.jpeg
# Processed Image 323: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0987-0001.jpeg
# Processed Image 324: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1138-0001.jpeg
# Processed Image 325: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1350-0001.jpeg
# Processed Image 326: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0709-0001.jpeg
# Processed Image 327: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0421-0001.jpeg
# Processed Image 328: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0882-0001.jpeg
# Processed Image 329: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1322-0001.jpeg
# Processed Image 330: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0164-0001.jpeg
# Processed Image 331: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1277-0001-0001.jpeg
# Processed Image 332: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0897-0001.jpeg
# Processed Image 333: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0602-0001.jpeg
# Processed Image 334: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0742-0001.jpeg
# Processed Image 335: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1051-0001.jpeg
# Processed Image 336: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0446-0001.jpeg
# Processed Image 337: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1131-0001.jpeg
# Processed Image 338: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0395-0001-0001.jpeg
# Processed Image 339: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0983-0001.jpeg
# Processed Image 340: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1347-0001.jpeg
# Processed Image 341: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0480-0001.jpeg
# Processed Image 342: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0269-0001.jpeg
# Processed Image 343: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0750-0001.jpeg
# Processed Image 344: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0555-0001-0002.jpeg
# Processed Image 345: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0634-0001.jpeg
# Processed Image 346: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1308-0001.jpeg
# Processed Image 347: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0815-0001.jpeg
# Processed Image 348: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1337-0001.jpeg
# Processed Image 349: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1102-0001.jpeg
# Processed Image 350: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1127-0001.jpeg
# Processed Image 351: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0851-0001-0002.jpeg
# Processed Image 352: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1202-0001.jpeg
# Processed Image 353: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0408-0001.jpeg
# Processed Image 354: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1106-0001.jpeg
# Processed Image 355: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0862-0001.jpeg
# Processed Image 356: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0523-0001.jpeg
# Processed Image 357: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1192-0001.jpeg
# Processed Image 358: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0714-0001.jpeg
# Processed Image 359: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1100-0001.jpeg
# Processed Image 360: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0523-0001.jpeg
# Processed Image 361: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0349-0001.jpeg
# Processed Image 362: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1286-0001.jpeg
# Processed Image 363: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1266-0001-0001.jpeg
# Processed Image 364: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0621-0001.jpeg
# Processed Image 365: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0879-0001.jpeg
# Processed Image 366: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0803-0001.jpeg
# Processed Image 367: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0395-0001-0002.jpeg
# Processed Image 368: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0251-0001.jpeg
# Processed Image 369: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0988-0001.jpeg
# Processed Image 370: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0571-0001.jpeg
# Processed Image 371: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0913-0001.jpeg
# Processed Image 372: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0522-0001.jpeg
# Processed Image 373: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0866-0001.jpeg
# Processed Image 374: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0131-0001.jpeg
# Processed Image 375: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0512-0001.jpeg
# Processed Image 376: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0456-0001.jpeg
# Processed Image 377: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0379-0001.jpeg
# Processed Image 378: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0831-0001.jpeg
# Processed Image 379: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0589-0001.jpeg
# Processed Image 380: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0860-0001.jpeg
# Processed Image 381: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0692-0001.jpeg
# Processed Image 382: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0627-0001.jpeg
# Processed Image 383: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0753-0001.jpeg
# Processed Image 384: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0410-0001.jpeg
# Processed Image 385: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0874-0001.jpeg
# Processed Image 386: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1317-0001.jpeg
# Processed Image 387: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0828-0001.jpeg
# Processed Image 388: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0693-0001.jpeg
# Processed Image 389: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0553-0001-0003.jpeg
# Processed Image 390: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0241-0001.jpeg
# Processed Image 391: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0403-0001.jpeg
# Processed Image 392: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0944-0001.jpeg
# Processed Image 393: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0666-0001-0001.jpeg
# Processed Image 394: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0790-0001.jpeg
# Processed Image 395: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1345-0001.jpeg
# Processed Image 396: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0285-0001.jpeg
# Processed Image 397: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0654-0001.jpeg
# Processed Image 398: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1194-0001.jpeg
# Processed Image 399: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0577-0001.jpeg
# Processed Image 400: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0585-0001.jpeg
# Processed Image 401: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0541-0001.jpeg
# Processed Image 402: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0547-0001.jpeg
# Processed Image 403: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0679-0001.jpeg
# Processed Image 404: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0776-0001.jpeg
# Processed Image 405: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0595-0001.jpeg
# Processed Image 406: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1241-0001.jpeg
# Processed Image 407: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0797-0001.jpeg
# Processed Image 408: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0383-0001.jpeg
# Processed Image 409: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1094-0001-0002.jpeg
# Processed Image 410: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0306-0001.jpeg
# Processed Image 411: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0291-0001.jpeg
# Processed Image 412: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0452-0001.jpeg
# Processed Image 413: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0570-0001.jpeg
# Processed Image 414: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0442-0001.jpeg
# Processed Image 415: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1371-0001.jpeg
# Processed Image 416: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0475-0001.jpeg
# Processed Image 417: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0395-0001.jpeg
# Processed Image 418: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1059-0001.jpeg
# Processed Image 419: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0832-0001.jpeg
# Processed Image 420: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0942-0001.jpeg
# Processed Image 421: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0416-0001.jpeg
# Processed Image 422: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0700-0001.jpeg
# Processed Image 423: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0182-0001.jpeg
# Processed Image 424: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0606-0001.jpeg
# Processed Image 425: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0189-0001.jpeg
# Processed Image 426: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0145-0001.jpeg
# Processed Image 427: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0554-0001.jpeg
# Processed Image 428: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0515-0001.jpeg
# Processed Image 429: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1406-0001.jpeg
# Processed Image 430: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0510-0001.jpeg
# Processed Image 431: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0384-0001.jpeg
# Processed Image 432: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0548-0001.jpeg
# Processed Image 433: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0684-0001-0001.jpeg
# Processed Image 434: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0833-0001.jpeg
# Processed Image 435: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0396-0001.jpeg
# Processed Image 436: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0663-0001.jpeg
# Processed Image 437: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1102-0001-0001.jpeg
# Processed Image 438: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0662-0001.jpeg
# Processed Image 439: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0695-0001.jpeg
# Processed Image 440: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0403-0001.jpeg
# Processed Image 441: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0466-0001.jpeg
# Processed Image 442: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0970-0001.jpeg
# Processed Image 443: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0618-0001-0001.jpeg
# Processed Image 444: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0651-0001.jpeg
# Processed Image 445: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0425-0001.jpeg
# Processed Image 446: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0330-0001.jpeg
# Processed Image 447: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1296-0001.jpeg
# Processed Image 448: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0694-0001.jpeg
# Processed Image 449: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0217-0001.jpeg
# Processed Image 450: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0168-0001.jpeg
# Processed Image 451: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1102-0001-0002.jpeg
# Processed Image 452: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0935-0001.jpeg
# Processed Image 453: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0843-0001.jpeg
# Processed Image 454: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1179-0001.jpeg
# Processed Image 455: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-1025-0001.jpeg
# Processed Image 456: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0223-0001.jpeg
# Processed Image 457: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0301-0001.jpeg
# Processed Image 458: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0863-0001.jpeg
# Processed Image 459: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0367-0001.jpeg
# Processed Image 460: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0734-0001.jpeg
# Processed Image 461: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0626-0001-0002.jpeg
# Processed Image 462: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0730-0001.jpeg
# Processed Image 463: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0774-0001.jpeg
# Processed Image 464: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/NORMAL2-IM-0887-0001.jpeg
# Processed Image 465: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0644-0001-0001.jpeg
# Processed Image 466: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0245-0001.jpeg
# Processed Image 467: /kaggle/input/chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0227-0001.jpeg
# ...
# Processed Image 491: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person100_bacteria_482.jpeg
# Processed Image 492: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person142_bacteria_682.jpeg
# Processed Image 493: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1612_virus_2797.jpeg
# Processed Image 494: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person175_bacteria_834.jpeg
# Processed Image 495: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person151_bacteria_718.jpeg
# Processed Image 496: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person81_bacteria_398.jpeg
# Processed Image 497: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person25_virus_59.jpeg
# Processed Image 498: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person70_virus_130.jpeg
# Processed Image 499: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person101_bacteria_485.jpeg
# Processed Image 500: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person38_virus_83.jpeg
# Processed Image 501: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1649_virus_2850.jpeg
# Processed Image 502: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1631_virus_2826.jpeg
# Processed Image 503: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person53_virus_108.jpeg
# Processed Image 504: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person78_bacteria_380.jpeg
# Processed Image 505: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person139_bacteria_661.jpeg
# Processed Image 506: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1668_virus_2882.jpeg
# Processed Image 507: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person109_bacteria_523.jpeg
# Processed Image 508: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person21_virus_53.jpeg
# Processed Image 509: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person110_bacteria_531.jpeg
# Processed Image 510: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person139_bacteria_663.jpeg
# Processed Image 511: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person158_bacteria_742.jpeg
# Processed Image 512: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person161_bacteria_759.jpeg
# Processed Image 513: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person127_bacteria_603.jpeg
# Processed Image 514: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person147_bacteria_705.jpeg
# Processed Image 515: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person133_bacteria_635.jpeg
# Processed Image 516: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person51_virus_105.jpeg
# Processed Image 517: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person17_virus_48.jpeg
# Processed Image 518: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person44_virus_93.jpeg
# Processed Image 519: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person33_virus_72.jpeg
# Processed Image 520: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1629_virus_2823.jpeg
# Processed Image 521: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person92_bacteria_451.jpeg
# Processed Image 522: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person69_virus_129.jpeg
# Processed Image 523: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1642_virus_2842.jpeg
# Processed Image 524: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person54_virus_109.jpeg
# Processed Image 525: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person88_bacteria_438.jpeg
# Processed Image 526: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1640_virus_2839.jpeg
# Processed Image 527: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person121_bacteria_575.jpeg
# Processed Image 528: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1628_virus_2821.jpeg
# Processed Image 529: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person139_bacteria_666.jpeg
# Processed Image 530: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person80_bacteria_389.jpeg
# Processed Image 531: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person74_virus_135.jpeg
# Processed Image 532: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person78_bacteria_381.jpeg
# Processed Image 533: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person155_bacteria_731.jpeg
# Processed Image 534: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1674_virus_2890.jpeg
# Processed Image 535: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person130_bacteria_627.jpeg
# Processed Image 536: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person109_bacteria_513.jpeg
# Processed Image 537: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person71_virus_132.jpeg
# Processed Image 538: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person136_bacteria_650.jpeg
# Processed Image 539: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person96_bacteria_466.jpeg
# Processed Image 540: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person109_bacteria_526.jpeg
# Processed Image 541: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person34_virus_76.jpeg
# Processed Image 542: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person57_virus_113.jpeg
# Processed Image 543: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person109_bacteria_527.jpeg
# Processed Image 544: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person150_bacteria_717.jpeg
# Processed Image 545: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person119_bacteria_568.jpeg
# Processed Image 546: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person85_bacteria_422.jpeg
# Processed Image 547: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person134_bacteria_643.jpeg
# Processed Image 548: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person153_bacteria_726.jpeg
# Processed Image 549: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person83_bacteria_411.jpeg
# Processed Image 550: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1675_virus_2891.jpeg
# Processed Image 551: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1651_virus_2855.jpeg
# Processed Image 552: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1_virus_9.jpeg
# Processed Image 553: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person104_bacteria_492.jpeg
# Processed Image 554: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1653_virus_2858.jpeg
# Processed Image 555: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person76_virus_138.jpeg
# Processed Image 556: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1653_virus_2859.jpeg
# Processed Image 557: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1626_virus_2818.jpeg
# Processed Image 558: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person40_virus_87.jpeg
# Processed Image 559: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person30_virus_69.jpeg
# Processed Image 560: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person112_bacteria_539.jpeg
# Processed Image 561: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person157_bacteria_735.jpeg
# Processed Image 562: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person126_bacteria_600.jpeg
# Processed Image 563: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person127_bacteria_602.jpeg
# Processed Image 564: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person150_bacteria_716.jpeg
# Processed Image 565: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person81_bacteria_395.jpeg
# Processed Image 566: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person126_bacteria_599.jpeg
# Processed Image 567: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person136_bacteria_649.jpeg
# Processed Image 568: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person113_bacteria_540.jpeg
# Processed Image 569: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1661_virus_2873.jpeg
# Processed Image 570: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person109_bacteria_519.jpeg
# Processed Image 571: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person124_bacteria_591.jpeg
# Processed Image 572: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person124_bacteria_592.jpeg
# Processed Image 573: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person39_virus_85.jpeg
# Processed Image 574: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1643_virus_2843.jpeg
# Processed Image 575: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person78_bacteria_385.jpeg
# Processed Image 576: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person38_virus_84.jpeg
# Processed Image 577: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1633_virus_2829.jpeg
# Processed Image 578: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1627_virus_2819.jpeg
# Processed Image 579: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1662_virus_2875.jpeg
# Processed Image 580: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person103_bacteria_488.jpeg
# Processed Image 581: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person120_bacteria_570.jpeg
# Processed Image 582: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person67_virus_126.jpeg
# Processed Image 583: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person15_virus_46.jpeg
# Processed Image 584: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person143_bacteria_689.jpeg
# Processed Image 585: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person154_bacteria_728.jpeg
# Processed Image 586: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1669_virus_2884.jpeg
# Processed Image 587: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person31_virus_70.jpeg
# Processed Image 588: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person87_bacteria_434.jpeg
# Processed Image 589: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person147_bacteria_707.jpeg
# Processed Image 590: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person82_bacteria_405.jpeg
# Processed Image 591: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1669_virus_2885.jpeg
# Processed Image 592: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person64_virus_122.jpeg
# Processed Image 593: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person161_bacteria_762.jpeg
# Processed Image 594: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1613_virus_2799.jpeg
# Processed Image 595: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person122_bacteria_584.jpeg
# Processed Image 596: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person37_virus_82.jpeg
# Processed Image 597: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person147_bacteria_711.jpeg
# Processed Image 598: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person92_bacteria_450.jpeg
# Processed Image 599: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person91_bacteria_447.jpeg
# Processed Image 600: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person85_bacteria_421.jpeg
# Processed Image 601: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person103_bacteria_489.jpeg
# Processed Image 602: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person135_bacteria_646.jpeg
# Processed Image 603: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1612_virus_2798.jpeg
# Processed Image 604: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person173_bacteria_829.jpeg
# Processed Image 605: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person136_bacteria_652.jpeg
# Processed Image 606: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person130_bacteria_623.jpeg
# Processed Image 607: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person126_bacteria_598.jpeg
# Processed Image 608: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person85_bacteria_424.jpeg
# Processed Image 609: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person109_bacteria_528.jpeg
# Processed Image 610: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person82_bacteria_404.jpeg
# Processed Image 611: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person22_virus_54.jpeg
# Processed Image 612: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person114_bacteria_545.jpeg
# Processed Image 613: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person78_bacteria_386.jpeg
# Processed Image 614: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person172_bacteria_827.jpeg
# Processed Image 615: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1_virus_8.jpeg
# Processed Image 616: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1641_virus_2840.jpeg
# Processed Image 617: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person43_virus_92.jpeg
# Processed Image 618: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1608_virus_2786.jpeg
# Processed Image 619: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1655_virus_2861.jpeg
# Processed Image 620: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1659_virus_2867.jpeg
# Processed Image 621: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1615_virus_2801.jpeg
# Processed Image 622: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person1664_virus_2877.jpeg
# Processed Image 623: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person111_bacteria_536.jpeg
# Processed Image 624: /kaggle/input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/person152_bacteria_724.jpeg
#
# Finished processing test dataset. Total images processed: 624
#
# Final Evaluation Metrics:
# ╒═══════╤════════════════╤═════════════════╤════════════════════════════╤═══════════════════╤════════════════╤═════════════════════════════════╕
# │       │   Accuracy (%) │   Precision (%) │   Recall (Sensitivity) (%) │   Specificity (%) │   F1 Score (%) │   False Positive Rate (FPR) (%) │
# ╞═══════╪════════════════╪═════════════════╪════════════════════════════╪═══════════════════╪════════════════╪═════════════════════════════════╡
# │ train │          91.72 │           97.39 │                      91.3  │             92.92 │          94.25 │                            7.08 │
# ├───────┼────────────────┼─────────────────┼────────────────────────────┼───────────────────┼────────────────┼─────────────────────────────────┤
# │ val   │          62.5  │           60    │                      75    │             50    │          66.67 │                           50    │
# ├───────┼────────────────┼─────────────────┼────────────────────────────┼───────────────────┼────────────────┼─────────────────────────────────┤
# │ test  │          82.21 │           81.07 │                      93.33 │             63.68 │          86.77 │                           36.32 │
# ╘═══════╧════════════════╧═════════════════╧════════════════════════════╧═══════════════════╧════════════════╧═════════════════════════════════╛

# %%
import pandas as pd

# Rename columns for conciseness
df = df.rename(columns={
    "Accuracy (%)": "Acc (%)",
    "Precision (%)": "Prec (%)",
    "Recall (Sensitivity) (%)": "Rec (%)",
    "Specificity (%)": "Spec (%)",
    "F1 Score (%)": "F1 (%)",
    "False Positive Rate (FPR) (%)": "FPR (%)"
})

# Round metrics to 2 decimal places
df = df.round(2)

# Print neatly formatted table
print("\nFinal Evaluation Metrics for Journal:")
print(df.to_markdown(tablefmt="fancy_grid"))

# Save in multiple formats
df.to_csv("evaluation_metrics.csv", index=True)      # CSV format
df.to_latex("evaluation_metrics.tex", index=True)    # LaTeX format (for journals)
# Out:
# Final Evaluation Metrics for Journal:
# ╒═══════╤═══════════╤════════════╤═══════════╤════════════╤══════════╤═══════════╕
# │       │   Acc (%) │   Prec (%) │   Rec (%) │   Spec (%) │   F1 (%) │   FPR (%) │
# ╞═══════╪═══════════╪════════════╪═══════════╪════════════╪══════════╪═══════════╡
# │ train │     91.72 │      97.39 │     91.3  │      92.92 │    94.25 │      7.08 │
# ├───────┼───────────┼────────────┼───────────┼────────────┼──────────┼───────────┤
# │ val   │     62.5  │      60    │     75    │      50    │    66.67 │     50    │
# ├───────┼───────────┼────────────┼───────────┼────────────┼──────────┼───────────┤
# │ test  │     82.21 │      81.07 │     93.33 │      63.68 │    86.77 │     36.32 │
# ╘═══════╧═══════════╧════════════╧═══════════╧════════════╧══════════╧═══════════╛

# %%
import pandas as pd

# Manually set the total number of images per dataset split
image_counts = {"train": 5216, "val": 16, "test": 624}

# If "Images" column already exists, update it; otherwise, insert it
if "Images" in df.columns:
    df["Images"] = df.index.map(image_counts)
else:
    df.insert(2, "Images", df.index.map(image_counts))

# Rename columns for conciseness
df = df.rename(columns={
    "Accuracy (%)": "Acc (%)",
    "Precision (%)": "Prec (%)",
    "Recall (Sensitivity) (%)": "Rec (%)",
    "Specificity (%)": "Spec (%)",
    "F1 Score (%)": "F1 (%)",
    "False Positive Rate (FPR) (%)": "FPR (%)"
})

# Round metrics to 2 decimal places
df = df.round(2)

# Select train and test for the final formatted table
df_combined = df.loc[["train", "test"]]

# Print the structured table with train & test metrics
print("\nFinal Evaluation Metrics (Train & Test):")
print(df_combined.to_markdown(tablefmt="fancy_grid"))

# Save in multiple formats for journal submission
df_combined.to_csv("evaluation_metrics_train_test.csv", index=True)      # CSV format
df_combined.to_latex("evaluation_metrics_train_test.tex", index=True)    # LaTeX format (for journals)
# Out:
# Final Evaluation Metrics (Train & Test):
# ╒═══════╤═══════════╤════════════╤═══════════╤════════════╤══════════╤═══════════╤══════════╕
# │       │   Acc (%) │   Prec (%) │   Rec (%) │   Spec (%) │   F1 (%) │   FPR (%) │   Images │
# ╞═══════╪═══════════╪════════════╪═══════════╪════════════╪══════════╪═══════════╪══════════╡
# │ train │     91.72 │      97.39 │     91.3  │      92.92 │    94.25 │      7.08 │     5216 │
# ├───────┼───────────┼────────────┼───────────┼────────────┼──────────┼───────────┼──────────┤
# │ test  │     82.21 │      81.07 │     93.33 │      63.68 │    86.77 │     36.32 │      624 │
# ╘═══════╧═══════════╧════════════╧═══════════╧════════════╧══════════╧═══════════╧══════════╛

# %%
print(df.columns)
print(df)
# Out:
# Index(['Acc (%)', 'Prec (%)', 'Rec (%)', 'Spec (%)', 'F1 (%)', 'FPR (%)',
#        'Images'],
#       dtype='object')
#        Acc (%)  Prec (%)  Rec (%)  Spec (%)  F1 (%)  FPR (%)  Images
# train    91.72     97.39    91.30     92.92   94.25     7.08  5216.0
# val      62.50     60.00    75.00     50.00   66.67    50.00     NaN
# test     82.21     81.07    93.33     63.68   86.77    36.32   624.0
#
# Final Combined Metrics (Train + Test):
# ╒══════════════╤══════════╤═══════════╤════════════╤═══════════╤════════════╤══════════╤═══════════╕
# │              │   Images │   Acc (%) │   Prec (%) │   Rec (%) │   Spec (%) │   F1 (%) │   FPR (%) │
# ╞══════════════╪══════════╪═══════════╪════════════╪═══════════╪════════════╪══════════╪═══════════╡
# │ Train + Test │     5840 │      90.7 │      95.65 │     91.52 │       89.8 │    93.45 │      10.2 │
# ╘══════════════╧══════════╧═══════════╧════════════╧═══════════╧════════════╧══════════╧═══════════╛
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()

# %%
import pandas as pd

# Define total images for train, val, and test
image_counts = {"train": 5216, "val": 12, "test": 624}

# Ensure "Images" column is correctly assigned
for split in image_counts:
    df.loc[split, "Images"] = image_counts[split]

# Select all three splits (train, val, test)
df_all = df.loc[["train", "val", "test"]]

# Compute total images across all splits
total_images = df_all["Images"].sum()

# Compute weighted averages for each metric
final_metrics = {"Images": total_images}

metrics_cols = [col for col in df.columns if col != "Images"]

for col in metrics_cols:
    final_metrics[col] = sum(df_all.loc[split, col] * image_counts[split] for split in image_counts) / total_images

# Convert to DataFrame
df_final = pd.DataFrame(final_metrics, index=["Train + Val + Test"]).round(2)

# Print final table
print("\nFinal Combined Metrics for Kaggle Chest X-ray Dataset:")
print(df_final.to_markdown(tablefmt="fancy_grid"))

# Save in multiple formats
df_final.to_csv("final_combined_metrics.csv", index=True)
df_final.to_latex("final_combined_metrics.tex", index=True)
# Out:
# Final Combined Metrics for Kaggle Chest X-ray Dataset:
# ╒════════════════════╤══════════╤═══════════╤════════════╤═══════════╤════════════╤══════════╤═══════════╕
# │                    │   Images │   Acc (%) │   Prec (%) │   Rec (%) │   Spec (%) │   F1 (%) │   FPR (%) │
# ╞════════════════════╪══════════╪═══════════╪════════════╪═══════════╪════════════╪══════════╪═══════════╡
# │ Train + Val + Test │     5852 │     90.65 │      95.57 │     91.48 │      89.71 │     93.4 │     10.29 │
# ╘════════════════════╧══════════╧═══════════╧════════════╧═══════════╧════════════╧══════════╧═══════════╛

# %%
import pandas as pd

# Define total images for train, val, and test
image_counts = {"train": 5216, "val": 12, "test": 624}

# Ensure "Images" column is correctly assigned
for split in image_counts:
    df.loc[split, "Images"] = image_counts[split]

# Select all three splits (train, val, test)
df_all = df.loc[["train", "val", "test"]]

# Compute total images across all splits
total_images = df_all["Images"].sum()

# Define full metric names
metric_names = {
    "Acc (%)": "Accuracy (%)",
    "Prec (%)": "Precision (%)",
    "Rec (%)": "Recall (Sensitivity, TPR) (%)",
    "Spec (%)": "Specificity (TNR) (%)",
    "F1 (%)": "F1 Score (%)",
    "FPR (%)": "False Positive Rate (FPR) (%)",
    "Images": "Total Images Processed"
}

# Compute weighted averages for each metric
final_metrics = {"Total Images Processed": total_images}

metrics_cols = [col for col in df.columns if col != "Images"]

for col in metrics_cols:
    final_metrics[metric_names[col]] = sum(df_all.loc[split, col] * image_counts[split] for split in image_counts) / total_images

# Convert to DataFrame with full metric names
df_final = pd.DataFrame(final_metrics.items(), columns=["Metric", "Value"]).round(4)

# Print final table
print("\nFinal Combined Metrics for Kaggle Chest X-ray Dataset:")
print(df_final.to_markdown(tablefmt="fancy_grid"))

# Save in multiple formats
df_final.to_csv("final_combined_metrics.csv", index=False)
df_final.to_latex("final_combined_metrics.tex", index=False)
# Out:
# Final Combined Metrics for Kaggle Chest X-ray Dataset:
# ╒════╤═══════════════════════════════╤═══════════╕
# │    │ Metric                        │     Value │
# ╞════╪═══════════════════════════════╪═══════════╡
# │  0 │ Total Images Processed        │ 5852      │
# ├────┼───────────────────────────────┼───────────┤
# │  1 │ Accuracy (%)                  │   90.646  │
# ├────┼───────────────────────────────┼───────────┤
# │  2 │ Precision (%)                 │   95.5731 │
# ├────┼───────────────────────────────┼───────────┤
# │  3 │ Recall (Sensitivity, TPR) (%) │   91.483  │
# ├────┼───────────────────────────────┼───────────┤
# │  4 │ Specificity (TNR) (%)         │   89.7141 │
# ├────┼───────────────────────────────┼───────────┤
# │  5 │ F1 Score (%)                  │   93.3959 │
# ├────┼───────────────────────────────┼───────────┤
# │  6 │ False Positive Rate (FPR) (%) │   10.2859 │
# ╘════╧═══════════════════════════════╧═══════════╛
